# %%
import pandas as pd

df = pd.read_csv("data.csv")["ETHBTC Close"]
print(df.tail())
# Out:
# 4314    0.091376
# 4315    0.091457
# 4316    0.091471
# 4317    0.091385
# 4318    0.091344
# Name: ETHBTC Close, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

df.plot()

# %%
import sklearn.linear_model as linear
